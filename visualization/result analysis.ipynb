# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
labels=['correct','discorrect']
X=[360+5635,8570-357-5635]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("Correct rate")
  
 
# plt.show()  
plt.savefig("/home/ytikewk/python_project/daisee_detect/figures/enclass.jpg")

# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
labels=['correct','discorrect']
X=[390+5635,8570-357-5635]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("Correct rate")
  
 
# plt.show()  
plt.savefig("/home/ytikewk/python_project/daisee_detect/figures/diclass.jpg")

# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
labels=['very low engaged','low engaged','high engaged','very high engaged']
X=[61,455,4421,3984]  
 #2: 4421, 3: 3984, 1: 455, 0: 61}
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("")
  
 
# plt.show()  
plt.savefig("4_level_pie.jpg")

# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
labels=['disengaged','engaged']
X=[61+455,4421+3984]  
 #2: 4421, 3: 3984, 1: 455, 0: 61}
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("Correct rate")
  
 
# plt.show()  
plt.savefig("2_level_pie.jpg")

# %%
import os
os.getcwd()
# Out:
# '/home/ytikewk/python_project/daisee_detect'

# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
labels=['very low engaged','low engaged','high engaged','very high engaged']
X=[61,455,4421,3984]  
 #2: 4421, 3: 3984, 1: 455, 0: 61}
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
plt.title("Correct rate")
  
 
plt.show()  
plt.savefig("4_level_pie.jpg")
labels=['disengage','engage']
X=[357,5635]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
plt.title("Engage rate in correct result")
  
 
plt.show()  
# plt.savefig("PieChart.jpg")

# %%
labels=['AUs','gaze','pose']
X=[116,15,226]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("feature importance for disengaged")
  
 
# plt.show()  
plt.savefig("fidis.jpg")

# %%
import os
os.getcwd()
# Out:
# '/home/ytikewk/python_project/daisee_detect'

# %%
labels=['AUs','gaze','pose']
X=[975,243,4417]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
# plt.title("feature importance for engaged")
  
 
# plt.show()  
plt.savefig("fien.jpg")

# %%
labels=['gaze','pose']
X=[23,334]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
plt.title("feature importance for disengaged(no statistic)")
  
 
plt.show()  
# plt.savefig("PieChart.jpg")

# %%
labels=['gaze','pose']
X=[40,5595]  
 
fig = plt.figure()
plt.pie(X,labels=labels,autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
plt.title("feature importance for engaged(no statistic)")
  
 
plt.show()  
# plt.savefig("PieChart.jpg")
